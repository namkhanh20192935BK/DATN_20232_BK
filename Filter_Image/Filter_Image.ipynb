# %% [markdown]
# # Áp dụng bộ lọc trung vị

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('test4.PNG',0)
output_image = cv2.medianBlur(image, 7)
output_image_2 = cv2.medianBlur(image, 5)

# Hiển thị 3 hình ảnh trên cùng một hàng
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Binary Image')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(output_image, cmap='gray')
plt.title('Bộ lọc trung bình 7x7')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(output_image_2, cmap='gray')
plt.title('Bộ lọc trung bình 5x5')
plt.axis('off')

plt.show()

# %% [markdown]
# # Sử dụng toán tử trạng thái

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('test4.PNG',0)
output_image = cv2.medianBlur(image, 7)
output_image = cv2.medianBlur(output_image, 7)
output_image_2 = cv2.medianBlur(image, 5)
output_image_2 = cv2.medianBlur(output_image_2, 5)

# Hiển thị 3 hình ảnh trên cùng một hàng
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Binary Image')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(output_image, cmap='gray')
plt.title('Bộ lọc trung bình 7x7')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(output_image_2, cmap='gray')
plt.title('Bộ lọc trung bình 5x5')
plt.axis('off')

plt.show()

# Đọc ảnh và chuyển đổi sang ảnh nhị phân
imageSrc = cv2.imread("test4.PNG", cv2.IMREAD_GRAYSCALE)

#ret, imageBinary = cv2.threshold(imageSrc, 0, 1, cv2.THRESH_BINARY)

# Khởi tạo kernel cho erosion và dilation
kernel1 = cv2.getStructuringElement(cv2.MORPH_ERODE, (7, 7)) # phép co
kernel2 = cv2.getStructuringElement(cv2.MORPH_DILATE, (7, 7)) # phép dãn nở

# Áp dụng phép co và phép dãn nở cho ảnh (Opening)
image1 = cv2.erode(output_image, kernel1)
image1 = cv2.dilate(image1, kernel2)

# Áp dụng phép dãn nở và phép co cho ảnh (Closing)
image2 = cv2.dilate(output_image, kernel2)
image2 = cv2.erode(image2, kernel1)

# Hiển thị 3 hình ảnh trên cùng một hàng
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(imageSrc, cmap='gray')
plt.title('Original Binary Image')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(image1, cmap='gray')
plt.title('Phép toán mở (Opening)')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(image2, cmap='gray')
plt.title('Phép toán đóng (Closing)')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Đọc ảnh và chuyển đổi sang ảnh nhị phân
imageSrc = cv2.imread("test5.PNG", cv2.IMREAD_COLOR)

# ret, imageBinary = cv2.threshold(imageSrc, 220, 255, cv2.THRESH_BINARY)

# Khởi tạo kernel cho erosion và dilation
kernel1 = cv2.getStructuringElement(cv2.MORPH_ERODE, (5, 5)) # phép co
kernel2 = cv2.getStructuringElement(cv2.MORPH_DILATE, (5, 5)) # phép dãn nở

# Áp dụng phép co và phép dãn nở cho ảnh
# image1 = cv2.erode(imageSrc, kernel1)
image1 = cv2.dilate(imageSrc, kernel2)

fig = plt.figure(figsize=(16, 9))     # Thiết lập vùng (cửa sổ) vẽ
ax1, ax2 = fig.subplots(1, 2)        # Thiết lập 2 vùng con ax1, ax2
ax1.imshow(imageSrc, cmap='gray')      # Hiển thị ảnh gốc vùng ax1
ax1.set_title("ảnh nhiễu Gaussian")             # Thiết lập tiêu đề vùng ax1
ax1.axis("off")

ax2.imshow(image1, cmap='gray')       # Hiển thị ảnh sau khi lọc
ax2.set_title("Sau khi thực hiện phép co") # Thiết lập tiêu đề vùng ax2
ax2.axis("off")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Đọc ảnh và chuyển đổi sang ảnh nhị phân
imageSrc = cv2.imread("4.PNG", cv2.IMREAD_COLOR)

# ret, imageBinary = cv2.threshold(imageSrc, 220, 255, cv2.THRESH_BINARY)

# Khởi tạo kernel cho erosion và dilation
kernel1 = cv2.getStructuringElement(cv2.MORPH_ERODE, (5, 5)) # phép co
kernel2 = cv2.getStructuringElement(cv2.MORPH_DILATE, (5, 5)) # phép dãn nở

# Áp dụng phép co và phép dãn nở cho ảnh (Opening)
image1 = cv2.erode(imageSrc, kernel1)
image1 = cv2.dilate(image1, kernel2)

# Áp dụng phép dãn nở và phép co cho ảnh (Closing)
image2 = cv2.dilate(imageSrc, kernel2)
image2 = cv2.erode(image2, kernel1)

# Hiển thị 3 hình ảnh trên cùng một hàng
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(imageSrc, cmap='gray')
plt.title('Original Binary Image')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(image1, cmap='gray')
plt.title('Phép toán mở (Opening)')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(image2, cmap='gray')
plt.title('Phép toán đóng (Closing)')
plt.axis('off')

plt.show()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

smooth = 1e-5

def Loc_Thich_Nghi_Cuc_Bo(img, ksize, phuong_sai_nhieu):
    m, n = img.shape
    img_ket_qua_anh_loc = np.zeros([m, n])
    h = (ksize - 1) // 2
    padded_img = np.pad(img, (h, h), mode='reflect')
    
    for i in range(m):
        for j in range(n):
            # Check for NaN values in your array
            if np.isnan(padded_img[i, j]):
                # Handle NaN values here (e.g., replace with 0)
                padded_img[i, j] = 0.0
            
            vung_anh_kich_thuoc_k = padded_img[i:i+ksize, j:j+ksize]
            phuong_sai_cuc_bo = np.var(vung_anh_kich_thuoc_k)
            gia_tri_TB_cuc_bo = np.mean(vung_anh_kich_thuoc_k)
            
            if gia_tri_TB_cuc_bo > phuong_sai_nhieu:
                img_ket_qua_anh_loc[i, j] = gia_tri_TB_cuc_bo
            else:
                img_ket_qua_anh_loc[i, j] = padded_img[i, j] - int((phuong_sai_nhieu / (phuong_sai_cuc_bo + smooth)) * (padded_img[i, j] - gia_tri_TB_cuc_bo))
    
    return img_ket_qua_anh_loc

img_nhieu = cv2.imread('9.JPG', 0)
phuong_sai_nhieu = 0.15
ksize = 7

# Gọi hàm xử lý ảnh
img_ket_qua = Loc_Thich_Nghi_Cuc_Bo(img_nhieu, ksize, phuong_sai_nhieu)

fig = plt.figure(figsize=(16, 9))     # Thiết lập vùng (cửa sổ) vẽ
ax1, ax2 = fig.subplots(1, 2)        # Thiết lập 2 vùng con ax1, ax2
ax1.imshow(img_nhieu, cmap='gray')      # Hiển thị ảnh gốc vùng ax1
ax1.set_title("ảnh nhiễu Gaussian")             # Thiết lập tiêu đề vùng ax1
ax1.axis("off")

ax2.imshow(img_ket_qua, cmap='gray')       # Hiển thị ảnh sau khi lọc
ax2.set_title("ảnh sau khi qua Bộ lọc thích nghi cục bộ") # Thiết lập tiêu đề vùng ax2
ax2.axis("off")
plt.show()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

def Loc_Trung_Vi_thich_nghi(img,ksize,Smax):     # Định nghĩa hàm lọc trung vị thích nghi
    m,n = img.shape  # lấy 2 chiều của ảnh
    img_ket_qua_anh_loc= np.zeros([m, n]) # Tạo ma trận có kích thước bằng kích thước mxn
                                          # để lưu ảnh kết quả lọc
    h = (Smax-1)//2    # Thêm số pixel vào lề ảnh. Chú ý nếu bộ lọc có kích thước K thì:
                       # số pixel thêm vào mỗi lề ảnh (chú ý: ảnh có 4 lề) là (K-1)/2
    padded_img = np.pad(img,(h,h),mode='reflect')  #Thêm lề ảnh
    for i in range(m):
        for j in range(n):
            k = ksize
            vung_anh_kich_thuoc_k = padded_img[i:i+k,j:j+k] # tạo vùng lân cận (i,j)
                                                                     # Và cũng chính là vùng Sxy
            while True:
                # Bước A
                A1 = np.median(vung_anh_kich_thuoc_k) - np.min(vung_anh_kich_thuoc_k)
                A2 = np.median(vung_anh_kich_thuoc_k) - np.max(vung_anh_kich_thuoc_k)
                if A1 > 0 and A2 <0:
                    # Đi đến Bước B
                    # Chú ý: Giữ liệu các pixel số nguyên trong vùng [0..255]
                    # Nếu không chuyển sang int khi trừ thì chương trình sẽ cảnh báo
                    B1 = int(img[i, j]) - int(np.min(vung_anh_kich_thuoc_k))
                    B2 = int(img[i, j]) - int(np.max(vung_anh_kich_thuoc_k))
                    if B1>0 and B2 <0:
                        img_ket_qua_anh_loc[i,j] = img[i,j]
                    else:
                        img_ket_qua_anh_loc[i, j] = np.median(vung_anh_kich_thuoc_k)
                    break  # Thoát khỏi lặp
                else: # Quay lại bước A
                    k += 1
                    Snew = k*2+1
                    if Snew <= Smax :
                        vung_anh_kich_thuoc_k = padded_img[i:i+k,j:j+k]
                    else :
                        img_ket_qua_anh_loc[i,j] = np.median(vung_anh_kich_thuoc_k)
                        break # Thoát khỏi lặp
    return img_ket_qua_anh_loc

if __name__ == "__main__":
    img_nhieu = cv2.imread('9.JPG',0) # Đọc ảnh
    ksize=7   # Kích thước khởi tạo của bộ lọc thường là số lẽ
    Smax=11    # Kích thước tối đa của bộ lọc
    img_ket_qua = Loc_Trung_Vi_thich_nghi(img_nhieu,ksize, Smax)    #Gọi hàm lọc trung vị

    fig = plt.figure(figsize=(16, 9))     # Thiết lập vùng (cửa sổ) vẽ
    ax1, ax2 = fig.subplots(1, 2)        # Thiết lập 2 vùng con ax1, ax2
    ax1.imshow(img_nhieu, cmap='gray')      # Hiển thị ảnh gốc vùng ax1
    ax1.set_title("ảnh nhiễu muối tiêu")    # Thiết lập tiêu đề vùng ax1
    ax1.axis("off")

    ax2.imshow(img_ket_qua, cmap='gray') # Hiển thị ảnh sau khi lọc
    ax2.set_title("ảnh sau khi qua Bộ lọc trung vị thích nghi") # Thiết lập tiêu đề vùng ax2
    ax2.axis("off")

    plt.show()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt


def Loc_TKTT_Midpoint(img, ksize):
    m, n = img.shape
    img_ket_qua_anh_loc_Midpoint = np.zeros([m, n])
    h=(ksize -1) // 2
    padded_img = np.pad(img, (h, h), mode='reflect')
    for i in range(m):
        for j in range(n):
            vung_anh_kich_thuoc_k = padded_img[i:i+ksize,j:j+ksize]
            gia_tri_Max = np.max(vung_anh_kich_thuoc_k)
            gia_tri_Min = np.min(vung_anh_kich_thuoc_k)
            img_ket_qua_anh_loc_Midpoint[i, j] = (gia_tri_Max + gia_tri_Min)/2
    return img_ket_qua_anh_loc_Midpoint

def Loc_Trung_binh_cat_Alpha(img, ksize, alpha):
    m,n = img.shape
    img_LQ_Trung_binh_cat_Alpha = np.zeros([m, n])
    h = (ksize - 1) // 2
    d = int(ksize*ksize*alpha)
    padded_img = np.pad(img,(h,h),mode='reflect')
    for i in range(m):
        for j in range(n):
            vung_anh_kich_thuoc_k = padded_img[i:i+ksize,j:j+ksize].flatten()
            vung_anh_kich_thuoc_k.sort()
            vung_anh_kich_thuoc_con_lai = vung_anh_kich_thuoc_k[d//2:-d//2]
            img_LQ_Trung_binh_cat_Alpha[i,j] = np.sum(vung_anh_kich_thuoc_con_lai) / (m*n-d)
    return img_LQ_Trung_binh_cat_Alpha

if __name__ == "__main__":

    img_nhieu_hat_tieu = cv2.imread('9.JPG', 0)
    img_nhieu_muoi = cv2.imread('9.JPG', 0)
    img_nhieu_dong_nhat = cv2.imread('9.JPG', 0)
    ksize = 5 # Để lọc ảnh Midpoint
    alpha = 0.25

    img_KQ_MidPoint= Loc_TKTT_Midpoint(img_nhieu_dong_nhat , ksize)
    img_KQ_TBCA = Loc_Trung_binh_cat_Alpha(img_nhieu_dong_nhat, ksize, alpha)

    fig = plt.figure(figsize=(16, 9))     # Thiết lập vùng (cửa sổ) vẽ
    (ax1, ax2), (ax3,ax4) = fig.subplots(2, 2)        # Thiết lập 2 vùng con ax1, ax2
    ax1.imshow(img_nhieu_dong_nhat, cmap='gray')      # Hiển thị ảnh gốc vùng ax1
    ax1.set_title("ảnh gốc bị nhiễu đồng nhất")             # Thiết lập tiêu đề vùng ax1
    ax1.axis("off")

    ax2.imshow(img_KQ_MidPoint, cmap='gray')       # Hiển thị ảnh sau khi lọc
    ax2.set_title("ảnh sau khi lọc MidPoint") # Thiết lập tiêu đề vùng ax2
    ax2.axis("off")

    ax3.axis("off")

    ax4.imshow(img_KQ_TBCA, cmap='gray')  # Hiển thị ảnh sau khi lọc
    ax4.set_title("ảnh sau khi lọc cắt TB Alpha")  # Thiết lập tiêu đề vùng ax2
    ax4.axis("off")

    plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15496\2251927325.py:16: RuntimeWarning: overflow encountered in scalar add
#   img_ket_qua_anh_loc_Midpoint[i, j] = (gia_tri_Max + gia_tri_Min)/2

# %%
img = cv2.imread('9.JPG', 1)
blur = cv2.medianBlur(img, 5)

fig = plt.figure(figsize=(16, 9))     # Thiết lập vùng (cửa sổ) vẽ
ax1, ax2 = fig.subplots(1, 2)        # Thiết lập 2 vùng con ax1, ax2
ax1.imshow(img, cmap='gray')      # Hiển thị ảnh gốc vùng ax1
ax1.set_title("ảnh ban đầu")    # Thiết lập tiêu đề vùng ax1
ax1.axis("off")

ax2.imshow(blur, cmap='gray') # Hiển thị ảnh sau khi lọc
ax2.set_title("ảnh sau khi qua Bộ lọc trung vị 5x5") # Thiết lập tiêu đề vùng ax2
ax2.axis("off")

plt.show()
